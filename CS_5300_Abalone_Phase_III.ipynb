# %% [markdown]
# <a href="https://colab.research.google.com/github/kilgorjn/CS_5300_AI/blob/main/CS_5300_Abalone_Phase_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phase III

# %%
import urllib.request
import os
import pandas as pd
from sklearn import preprocessing
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import timeit


if 'abalone.data' not in os.listdir():
  # !wget https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data
if 'abalone.names' not in os.listdir():
  # !wget https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.names


feature_names = ['Sex','Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight']
target_name = 'Rings'
names = feature_names + [target_name]
df = pd.read_csv('abalone.data', names=names) 

#convert the 'Sex' feature from nomimal to numerical 
df['Sex'] = df['Sex'].astype('category')
df['Sex'] = df['Sex'].cat.codes

#Convert the 'Rings' column to a binary 'Age', where 0 means 'young', and 1 means 'old'
df['Age'] = pd.DataFrame(np.where(df[target_name]<=9,0,1),columns=['Age'])
print(df.head())

#drop the 'Rings' feature, it is no longer needed
df.drop(labels='Rings', inplace=True, axis=1)
df.describe()  #un-normalized data


for column in ['Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight']:
  df[column] = (df[column]-df[column].min())/(df[column].max()-df[column].min())
df.describe()  #normalized data (all columns except Sex and Age)
# Out:
#    Sex  Length  Diameter  Height  ...  Viscera Weight  Shell Weight  Rings  Age
# 0    2   0.455     0.365   0.095  ...          0.1010         0.150     15    1
# 1    2   0.350     0.265   0.090  ...          0.0485         0.070      7    0
# 2    0   0.530     0.420   0.135  ...          0.1415         0.210      9    0
# 3    2   0.440     0.365   0.125  ...          0.1140         0.155     10    1
# 4    1   0.330     0.255   0.080  ...          0.0395         0.055      7    0
#
# [5 rows x 10 columns]
#                Sex       Length  ...  Shell Weight          Age
# count  4177.000000  4177.000000  ...   4177.000000  4177.000000
# mean      1.052909     0.606746  ...      0.236503     0.498204
# std       0.822240     0.162288  ...      0.138717     0.500057
# min       0.000000     0.000000  ...      0.000000     0.000000
# 25%       0.000000     0.506757  ...      0.128052     0.000000
# 50%       1.000000     0.635135  ...      0.231689     0.000000
# 75%       2.000000     0.729730  ...      0.326358     1.000000
# max       2.000000     1.000000  ...      1.000000     1.000000
#
# [8 rows x 9 columns]

# %%
#normalize the data in-place
for column in ['Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight','Shell Weight']:
  df[column] = (df[column]-df[column].min())/(df[column].max()-df[column].min())
df.describe()  #normalized data (all columns except Sex and Age)
# Out:
#                Sex       Length  ...  Shell Weight          Age
# count  4177.000000  4177.000000  ...   4177.000000  4177.000000
# mean      1.052909     0.606746  ...      0.236503     0.498204
# std       0.822240     0.162288  ...      0.138717     0.500057
# min       0.000000     0.000000  ...      0.000000     0.000000
# 25%       0.000000     0.506757  ...      0.128052     0.000000
# 50%       1.000000     0.635135  ...      0.231689     0.000000
# 75%       2.000000     0.729730  ...      0.326358     1.000000
# max       2.000000     1.000000  ...      1.000000     1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# # Split the data into training, validation,  and test sets

# %%
np.random.seed(0)  #set a seed to reproduce train and test sets over multiple runs
# msk = np.random.rand(len(df)) < 0.8

print('before shuffle')
print(df.head())
df = df.sample(frac=1, axis=0).reset_index(drop=True)
print('after shuffle')
print(df.head())


train_size = round(df.shape[0]*.7)
val_size = round(df.shape[0]*.2)
test_size = round(df.shape[0]*.1)

print(f'train_size = {train_size}:  val_size = {val_size}  test_size={test_size}')

df_x_train = df[0:train_size]
df_y_train = df_x_train['Age']
df_x_train = df_x_train.drop('Age', axis=1)

df_x_val = df[train_size:train_size+val_size]
df_y_val = df_x_val['Age']
df_x_val = df_x_val.drop('Age', axis=1)


df_x_test = df[train_size+val_size:train_size+val_size+test_size]
df_y_test = df_x_test['Age']
df_x_test = df_x_test.drop('Age', axis=1)


print(f'df shape: {df.shape}')
print(f'training shape(X): {df_x_train.shape}')
print(f'training shape(Y): {df_y_train.shape}')

print(f'validation shape(X): {df_x_val.shape}')
print(f'validation shape(Y): {df_y_val.shape}')


print(f'testing shape(X): {df_x_test.shape}')
print(f'testing shape(Y): {df_y_test.shape}')

print(df_x_train.head())
print(df_x_val.head())
print(df_x_test.head())
# Out:
# before shuffle
#    Sex    Length  Diameter  ...  Viscera Weight  Shell Weight  Age
# 0    2  0.513514  0.521008  ...        0.132324      0.147982    1
# 1    2  0.371622  0.352941  ...        0.063199      0.068261    0
# 2    0  0.614865  0.613445  ...        0.185648      0.207773    0
# 3    2  0.493243  0.521008  ...        0.149440      0.152965    1
# 4    1  0.344595  0.336134  ...        0.051350      0.053313    0
#
# [5 rows x 9 columns]
# after shuffle
#    Sex    Length  Diameter  ...  Viscera Weight  Shell Weight  Age
# 0    2  0.641892  0.621849  ...        0.319289      0.332337    1
# 1    1  0.574324  0.579832  ...        0.187623      0.191330    0
# 2    2  0.736486  0.714286  ...        0.491771      0.314898    1
# 3    1  0.195946  0.184874  ...        0.015142      0.018435    0
# 4    2  0.770270  0.747899  ...        0.493746      0.374689    1
#
# [5 rows x 9 columns]
# train_size = 2924:  val_size = 835  test_size=418
# df shape: (4177, 9)
# training shape(X): (2924, 8)
# training shape(Y): (2924,)
# validation shape(X): (835, 8)
# validation shape(Y): (835,)
# testing shape(X): (418, 8)
# testing shape(Y): (418,)
#    Sex    Length  Diameter  ...  Shucked Weight  Viscera Weight  Shell Weight
# 0    2  0.641892  0.621849  ...        0.185945        0.319289      0.332337
# 1    1  0.574324  0.579832  ...        0.174849        0.187623      0.191330
# 2    2  0.736486  0.714286  ...        0.353732        0.491771      0.314898
# 3    1  0.195946  0.184874  ...        0.013786        0.015142      0.018435
# 4    2  0.770270  0.747899  ...        0.452253        0.493746      0.374689
#
# [5 rows x 8 columns]
#       Sex    Length  Diameter  ...  Shucked Weight  Viscera Weight  Shell Weight
# 2924    0  0.486486  0.495798  ...        0.128447        0.131007      0.128052
# 2925    2  0.601351  0.605042  ...        0.172831        0.224490      0.252616
# 2926    1  0.459459  0.445378  ...        0.081036        0.096116      0.092177
# 2927    2  0.554054  0.554622  ...        0.133826        0.102699      0.167912
# 2928    2  0.824324  0.756303  ...        0.447882        0.533246      0.407075
#
# [5 rows x 8 columns]
#       Sex    Length  Diameter  ...  Shucked Weight  Viscera Weight  Shell Weight
# 3759    0  0.783784  0.815126  ...        0.466711        0.389072      0.440957
# 3760    2  0.391892  0.386555  ...        0.056826        0.067149      0.068261
# 3761    0  0.662162  0.672269  ...        0.244788        0.208690      0.257598
# 3762    0  0.675676  0.621849  ...        0.305313        0.236340      0.225710
# 3763    1  0.527027  0.521008  ...        0.155010        0.121132      0.111111
#
# [5 rows x 8 columns]

# %% [markdown]
# #  Create Utility Functions
# This cell just has utility functions for use evaluating different architectures

# %%
METRICS = [
      # keras.metrics.TruePositives(name='tp'),
      # keras.metrics.FalsePositives(name='fp'),
      # keras.metrics.TrueNegatives(name='tn'),
      # keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      # # keras.metrics.Precision(name='precision'),
      # keras.metrics.Recall(name='recall'),
      # keras.metrics.AUC(name='auc'),
]

###########################################################
# Build a model based on the provided architecture
###########################################################
def build_model(architecture:[], hidden_activation='relu', output_activation='sigmoid'):
  model = Sequential()
  model.add(Input(shape=df_x_train.shape[1]))
  # the architecture is a list of node_counts.  
  # Create a hidden layer w/ the specified 
  # number of nodes for each layer in the architecture.
  for nodes in architecture:
    model.add(Dense(nodes, activation=hidden_activation))  
  model.add(Dense(1, activation=output_activation))

  model.compile(
      optimizer=keras.optimizers.RMSprop(),
      loss = keras.losses.BinaryCrossentropy(),
      metrics = METRICS
      )
  return model





#########################################
# Function to train a model and return the training history.
# batch_size and epochs have defaults, but can be overridden
#########################################
def train_model(model, train_x, train_y, val_x, val_y, identifier, batch_size=64, epochs=256, use_early_stop=False):
  # print('--------Training model: ')
  # print(model.summary())
  print(f'training model {identifier}')

  callback_earlystop = EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1)
  callbacks = []
  if use_early_stop:
    callbacks.append(callback_earlystop)

  return model.fit(x=train_x, 
                    y=train_y, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_data=(val_x, val_y),
                    verbose=0,
                    callbacks=callbacks
                    )

def evaluate_model(model:tf.keras.Model, x_data, y_data):
  return model.evaluate(x_data, y_data, batch_size=128)

# %% [markdown]
# # Phase III

# %% [markdown]
# ## Recursive Feature Elimination

# %%
def recursive_feature_elimination():
  print(feature_names)
  for feature in feature_names:
    print(feature)
    val_accuracies = {}
    accuracies = {}
    # create new train and validation dataframes with only a single feature
    df_rde_x_train = df_x_train[feature].to_numpy()
    df_rde_x_val = df_x_val[feature].to_numpy()

    print(df_rde_x_train.shape)
  
    model = Sequential()
    model.add(Input(shape=1))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(
      optimizer=keras.optimizers.RMSprop(),
      loss = keras.losses.BinaryCrossentropy(),
      metrics = METRICS)    

    history = model.fit(x=df_rde_x_train, 
      y=df_y_train, 
      batch_size=64, 
      epochs=64, 
      validation_data=(df_rde_x_val, df_y_val),
      verbose=0,
      callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1)])
    val_accuracies[feature]=history.history['val_accuracy'][-1]
    accuracies[feature]=history.history['accuracy'][-1]
    print(feature,',',history.history['val_accuracy'][-1],',',history.history['accuracy'][-1])
  return (val_accuracies, accuracies)



(val_accuracies, accuracies) = recursive_feature_elimination()
print(val_accuracies)
print(accuracies)
# Out:
# ['Sex', 'Length', 'Diameter', 'Height', 'Whole Weight', 'Shucked Weight', 'Viscera Weight', 'Shell Weight']
# Sex
# (2924,)
# Epoch 00030: early stopping
# Sex , 0.6898203492164612 , 0.7058823704719543
# Length
# (2924,)
# Epoch 00037: early stopping
# Length , 0.6970059871673584 , 0.7250341773033142
# Diameter
# (2924,)
# Epoch 00055: early stopping
# Diameter , 0.7101796269416809 , 0.7308481335639954
# Height
# (2924,)
# Epoch 00020: early stopping
# Height , 0.7209580540657043 , 0.7482900023460388
# Whole Weight
# (2924,)
# Epoch 00032: early stopping
# Whole Weight , 0.7101796269416809 , 0.7322161197662354
# Shucked Weight
# (2924,)
# Shucked Weight , 0.682634711265564 , 0.6925444602966309
# Viscera Weight
# (2924,)
# Epoch 00031: early stopping
# Viscera Weight , 0.71257483959198 , 0.7393980622291565
# Shell Weight
# (2924,)
# Epoch 00046: early stopping
# Shell Weight , 0.7341317534446716 , 0.7609438896179199
# {'Shell Weight': 0.7341317534446716}
# {'Shell Weight': 0.7609438896179199}

# %% [markdown]
# From the data above, the features have been sorted by validation accuracy (small to large).  The sorted features are:
# 'Shucked Weight' ,'Sex' ,'Length' ,'Viscera Weight' ,'Whole Weight' ,'Diameter' ,'Height' ,'Shell Weight'

# %% [markdown]
# # Iteratively remove 1 feature at a time

# %%
features_sorted_small_to_large = ['Shucked Weight' ,'Sex' ,'Length' ,'Viscera Weight' ,'Whole Weight' ,'Diameter' ,'Height' ,'Shell Weight']

print(df_x_train.head())

df_rm_x_train = df_x_train.copy()
df_rm_x_train = df_rm_x_train[features_sorted_small_to_large]

df_rm_x_val = df_x_val.copy()
df_rm_x_val = df_rm_x_val[features_sorted_small_to_large]

# 
print(df_rm_x_train.head())

feature_removed = None
for feature in features_sorted_small_to_large:

  
  model = Sequential()
  model.add(Input(shape=df_rm_x_train.shape[1]))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  model.compile(
    optimizer=keras.optimizers.RMSprop(),
    loss = keras.losses.BinaryCrossentropy(),
    metrics = METRICS)    

  history = model.fit(x=df_rm_x_train, 
    y=df_y_train, 
    batch_size=64, 
    epochs=64, 
    validation_data=(df_rm_x_val, df_y_val),
    verbose=0,
    callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1)])

  print(df_rm_x_train.columns.values)
  print(f'After removing {feature_removed}',',',history.history['val_accuracy'][-1],',',history.history['accuracy'][-1])

  df_rm_x_train.drop([feature], axis=1, inplace=True)
  df_rm_x_val.drop([feature], axis=1, inplace=True)
  feature_removed = feature

# print(df_rm_x_train.head())
# print(df_x_val.head())
# Out:
#    Sex    Length  Diameter  ...  Shucked Weight  Viscera Weight  Shell Weight
# 0    2  0.641892  0.621849  ...        0.185945        0.319289      0.332337
# 1    1  0.574324  0.579832  ...        0.174849        0.187623      0.191330
# 2    2  0.736486  0.714286  ...        0.353732        0.491771      0.314898
# 3    1  0.195946  0.184874  ...        0.013786        0.015142      0.018435
# 4    2  0.770270  0.747899  ...        0.452253        0.493746      0.374689
#
# [5 rows x 8 columns]
#    Shucked Weight  Sex    Length  ...  Diameter    Height  Shell Weight
# 0        0.185945    2  0.641892  ...  0.621849  0.137168      0.332337
# 1        0.174849    1  0.574324  ...  0.579832  0.106195      0.191330
# 2        0.353732    2  0.736486  ...  0.714286  0.137168      0.314898
# 3        0.013786    1  0.195946  ...  0.184874  0.048673      0.018435
# 4        0.452253    2  0.770270  ...  0.747899  0.154867      0.374689
#
# [5 rows x 8 columns]
# Epoch 00060: early stopping
# ['Shucked Weight' 'Sex' 'Length' 'Viscera Weight' 'Whole Weight'
#  'Diameter' 'Height' 'Shell Weight']
# After removing None , 0.7664670944213867 , 0.8084815144538879
# Epoch 00061: early stopping
# ['Sex' 'Length' 'Viscera Weight' 'Whole Weight' 'Diameter' 'Height'
#  'Shell Weight']
# After removing Shucked Weight , 0.7556886076927185 , 0.7886456847190857
# Epoch 00064: early stopping
# ['Length' 'Viscera Weight' 'Whole Weight' 'Diameter' 'Height'
#  'Shell Weight']
# After removing Sex , 0.7497006058692932 , 0.7814637422561646
# Epoch 00057: early stopping
# ['Viscera Weight' 'Whole Weight' 'Diameter' 'Height' 'Shell Weight']
# After removing Length , 0.7556886076927185 , 0.7780437469482422
# Epoch 00063: early stopping
# ['Whole Weight' 'Diameter' 'Height' 'Shell Weight']
# After removing Viscera Weight , 0.7461077570915222 , 0.7804377675056458
# Epoch 00041: early stopping
# ['Diameter' 'Height' 'Shell Weight']
# After removing Whole Weight , 0.7353293299674988 , 0.770861804485321
# Epoch 00018: early stopping
# ['Height' 'Shell Weight']
# After removing Diameter , 0.7341317534446716 , 0.7633379101753235
# Epoch 00021: early stopping
# ['Shell Weight']
# After removing Height , 0.7365269660949707 , 0.7629958987236023

# %% [markdown]
# # Remove the 'Length' feature and compare

# %%
#Remove just the 'length' feature and compare the all features.

features_sorted_small_to_large = ['Shucked Weight' ,'Sex' ,'Length' ,'Viscera Weight' ,'Whole Weight' ,'Diameter' ,'Height' ,'Shell Weight']
features_to_remove = ['Length']

print(df_x_train.head())

df_rm_x_train = df_x_train.copy()
df_rm_x_train = df_rm_x_train[features_sorted_small_to_large]

df_rm_x_val = df_x_val.copy()
df_rm_x_val = df_rm_x_val[features_sorted_small_to_large]

# 
print(df_rm_x_train.head())

model = Sequential()
model.add(Input(shape=df_rm_x_train.shape[1]))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
  optimizer=keras.optimizers.RMSprop(),
  loss = keras.losses.BinaryCrossentropy(),
  metrics = METRICS)    

history = model.fit(x=df_rm_x_train, 
  y=df_y_train, 
  batch_size=64, 
  epochs=64, 
  validation_data=(df_rm_x_val, df_y_val),
  verbose=1,
  callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1)])



#drop the Length feature and retrain


df_rm_x_train.drop(['Length'], axis=1, inplace=True)
df_rm_x_val.drop(['Length'], axis=1, inplace=True)


model = Sequential()
model.add(Input(shape=df_rm_x_train.shape[1]))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
  optimizer=keras.optimizers.RMSprop(),
  loss = keras.losses.BinaryCrossentropy(),
  metrics = METRICS)    

history = model.fit(x=df_rm_x_train, 
  y=df_y_train, 
  batch_size=64, 
  epochs=64, 
  validation_data=(df_rm_x_val, df_y_val),
  verbose=1,
  callbacks=[EarlyStopping(monitor='val_loss', mode='min', patience=10, verbose=1)])
# Out:
#    Sex    Length  Diameter  ...  Shucked Weight  Viscera Weight  Shell Weight
# 0    2  0.641892  0.621849  ...        0.185945        0.319289      0.332337
# 1    1  0.574324  0.579832  ...        0.174849        0.187623      0.191330
# 2    2  0.736486  0.714286  ...        0.353732        0.491771      0.314898
# 3    1  0.195946  0.184874  ...        0.013786        0.015142      0.018435
# 4    2  0.770270  0.747899  ...        0.452253        0.493746      0.374689
#
# [5 rows x 8 columns]
#    Shucked Weight  Sex    Length  ...  Diameter    Height  Shell Weight
# 0        0.185945    2  0.641892  ...  0.621849  0.137168      0.332337
# 1        0.174849    1  0.574324  ...  0.579832  0.106195      0.191330
# 2        0.353732    2  0.736486  ...  0.714286  0.137168      0.314898
# 3        0.013786    1  0.195946  ...  0.184874  0.048673      0.018435
# 4        0.452253    2  0.770270  ...  0.747899  0.154867      0.374689
#
# [5 rows x 8 columns]
# Epoch 1/64
# 46/46 [==============================] - 1s 6ms/step - loss: 0.6636 - accuracy: 0.7074 - val_loss: 0.6205 - val_accuracy: 0.7006
# Epoch 2/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.7259 - val_loss: 0.5802 - val_accuracy: 0.7186
# Epoch 3/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5755 - accuracy: 0.7183 - val_loss: 0.5522 - val_accuracy: 0.7234
# Epoch 4/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.7562 - val_loss: 0.5535 - val_accuracy: 0.7341
# Epoch 5/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.7500 - val_loss: 0.5324 - val_accuracy: 0.7413
# Epoch 6/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.7537 - val_loss: 0.5231 - val_accuracy: 0.7425
# Epoch 7/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.7665 - val_loss: 0.5170 - val_accuracy: 0.7329
# Epoch 8/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7673 - val_loss: 0.5098 - val_accuracy: 0.7353
# Epoch 9/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7439 - val_loss: 0.5092 - val_accuracy: 0.7473
# Epoch 10/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7736 - val_loss: 0.5070 - val_accuracy: 0.7449
# Epoch 11/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7733 - val_loss: 0.5013 - val_accuracy: 0.7437
# Epoch 12/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7629 - val_loss: 0.4972 - val_accuracy: 0.7473
# Epoch 13/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7666 - val_loss: 0.4965 - val_accuracy: 0.7605
# Epoch 14/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7615 - val_loss: 0.4949 - val_accuracy: 0.7557
# Epoch 15/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4710 - accuracy: 0.7565 - val_loss: 0.5035 - val_accuracy: 0.7497
# Epoch 16/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.7778 - val_loss: 0.4873 - val_accuracy: 0.7545
# Epoch 17/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.7775 - val_loss: 0.4859 - val_accuracy: 0.7581
# Epoch 18/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7783 - val_loss: 0.4830 - val_accuracy: 0.7569
# Epoch 19/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7806 - val_loss: 0.5026 - val_accuracy: 0.7449
# Epoch 20/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.7838 - val_loss: 0.4792 - val_accuracy: 0.7581
# Epoch 21/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.7801 - val_loss: 0.4794 - val_accuracy: 0.7665
# Epoch 22/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7919 - val_loss: 0.4815 - val_accuracy: 0.7617
# Epoch 23/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.7836 - val_loss: 0.4828 - val_accuracy: 0.7557
# Epoch 24/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.7982 - val_loss: 0.4871 - val_accuracy: 0.7545
# Epoch 25/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7894 - val_loss: 0.4756 - val_accuracy: 0.7593
# Epoch 26/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.7914 - val_loss: 0.4790 - val_accuracy: 0.7641
# Epoch 27/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7884 - val_loss: 0.4723 - val_accuracy: 0.7665
# Epoch 28/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7847 - val_loss: 0.4797 - val_accuracy: 0.7629
# Epoch 29/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.8062 - val_loss: 0.4750 - val_accuracy: 0.7665
# Epoch 30/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4349 - accuracy: 0.7965 - val_loss: 0.4762 - val_accuracy: 0.7737
# Epoch 31/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.8027 - val_loss: 0.4700 - val_accuracy: 0.7629
# Epoch 32/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8038 - val_loss: 0.4732 - val_accuracy: 0.7641
# Epoch 33/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.8061 - val_loss: 0.4723 - val_accuracy: 0.7629
# Epoch 34/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.7991 - val_loss: 0.4736 - val_accuracy: 0.7725
# Epoch 35/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.7916 - val_loss: 0.4731 - val_accuracy: 0.7677
# Epoch 36/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.8051 - val_loss: 0.4688 - val_accuracy: 0.7641
# Epoch 37/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7581
# Epoch 38/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.7939 - val_loss: 0.4747 - val_accuracy: 0.7701
# Epoch 39/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.8018 - val_loss: 0.4761 - val_accuracy: 0.7713
# Epoch 40/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.8080 - val_loss: 0.4739 - val_accuracy: 0.7617
# Epoch 41/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.7985 - val_loss: 0.4929 - val_accuracy: 0.7569
# Epoch 42/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.7962 - val_loss: 0.4702 - val_accuracy: 0.7629
# Epoch 43/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4384 - accuracy: 0.7969 - val_loss: 0.4761 - val_accuracy: 0.7665
# Epoch 44/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4315 - accuracy: 0.7921 - val_loss: 0.4683 - val_accuracy: 0.7665
# Epoch 45/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4310 - accuracy: 0.8038 - val_loss: 0.4679 - val_accuracy: 0.7641
# Epoch 46/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4262 - accuracy: 0.8086 - val_loss: 0.4696 - val_accuracy: 0.7737
# Epoch 47/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.8066 - val_loss: 0.4684 - val_accuracy: 0.7689
# Epoch 48/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7842 - val_loss: 0.4700 - val_accuracy: 0.7713
# Epoch 49/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4240 - accuracy: 0.8016 - val_loss: 0.4698 - val_accuracy: 0.7617
# Epoch 50/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4360 - accuracy: 0.8033 - val_loss: 0.4733 - val_accuracy: 0.7569
# Epoch 51/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4307 - accuracy: 0.8006 - val_loss: 0.4695 - val_accuracy: 0.7689
# Epoch 52/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7832 - val_loss: 0.4918 - val_accuracy: 0.7605
# Epoch 53/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.7936 - val_loss: 0.4764 - val_accuracy: 0.7617
# Epoch 54/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4085 - accuracy: 0.8179 - val_loss: 0.4844 - val_accuracy: 0.7641
# Epoch 55/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.7995 - val_loss: 0.4756 - val_accuracy: 0.7653
# Epoch 00055: early stopping
# Epoch 1/64
# 46/46 [==============================] - 1s 6ms/step - loss: 0.6587 - accuracy: 0.6700 - val_loss: 0.6182 - val_accuracy: 0.6982
# Epoch 2/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5889 - accuracy: 0.7368 - val_loss: 0.5721 - val_accuracy: 0.7222
# Epoch 3/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7552 - val_loss: 0.5429 - val_accuracy: 0.7305
# Epoch 4/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5273 - accuracy: 0.7451 - val_loss: 0.5320 - val_accuracy: 0.7281
# Epoch 5/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.7517 - val_loss: 0.5157 - val_accuracy: 0.7257
# Epoch 6/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7628 - val_loss: 0.5225 - val_accuracy: 0.7377
# Epoch 7/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4955 - accuracy: 0.7487 - val_loss: 0.5160 - val_accuracy: 0.7401
# Epoch 8/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4813 - accuracy: 0.7617 - val_loss: 0.5021 - val_accuracy: 0.7521
# Epoch 9/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4801 - accuracy: 0.7625 - val_loss: 0.4948 - val_accuracy: 0.7437
# Epoch 10/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.7751 - val_loss: 0.4939 - val_accuracy: 0.7461
# Epoch 11/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7746 - val_loss: 0.4885 - val_accuracy: 0.7545
# Epoch 12/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4734 - accuracy: 0.7676 - val_loss: 0.5255 - val_accuracy: 0.7425
# Epoch 13/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.7681 - val_loss: 0.4827 - val_accuracy: 0.7593
# Epoch 14/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7609 - val_loss: 0.4802 - val_accuracy: 0.7509
# Epoch 15/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7747 - val_loss: 0.4796 - val_accuracy: 0.7617
# Epoch 16/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4510 - accuracy: 0.7859 - val_loss: 0.4751 - val_accuracy: 0.7605
# Epoch 17/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7857 - val_loss: 0.4725 - val_accuracy: 0.7605
# Epoch 18/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.7992 - val_loss: 0.4731 - val_accuracy: 0.7605
# Epoch 19/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7815 - val_loss: 0.4707 - val_accuracy: 0.7677
# Epoch 20/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.7835 - val_loss: 0.4771 - val_accuracy: 0.7641
# Epoch 21/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7794 - val_loss: 0.4919 - val_accuracy: 0.7557
# Epoch 22/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.7913 - val_loss: 0.4685 - val_accuracy: 0.7725
# Epoch 23/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7950 - val_loss: 0.4704 - val_accuracy: 0.7653
# Epoch 24/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4401 - accuracy: 0.7799 - val_loss: 0.4858 - val_accuracy: 0.7473
# Epoch 25/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.7978 - val_loss: 0.4762 - val_accuracy: 0.7725
# Epoch 26/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.8090 - val_loss: 0.4694 - val_accuracy: 0.7737
# Epoch 27/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.7949 - val_loss: 0.4685 - val_accuracy: 0.7689
# Epoch 28/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7776 - val_loss: 0.4678 - val_accuracy: 0.7701
# Epoch 29/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.7772 - val_loss: 0.4715 - val_accuracy: 0.7737
# Epoch 30/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.7776 - val_loss: 0.4656 - val_accuracy: 0.7629
# Epoch 31/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4217 - accuracy: 0.8069 - val_loss: 0.4648 - val_accuracy: 0.7617
# Epoch 32/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8071 - val_loss: 0.4845 - val_accuracy: 0.7593
# Epoch 33/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.7927 - val_loss: 0.4683 - val_accuracy: 0.7677
# Epoch 34/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.7978 - val_loss: 0.4866 - val_accuracy: 0.7653
# Epoch 35/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4262 - accuracy: 0.8065 - val_loss: 0.4719 - val_accuracy: 0.7701
# Epoch 36/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.8124 - val_loss: 0.4646 - val_accuracy: 0.7713
# Epoch 37/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4356 - accuracy: 0.7919 - val_loss: 0.4659 - val_accuracy: 0.7749
# Epoch 38/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.7954 - val_loss: 0.4716 - val_accuracy: 0.7665
# Epoch 39/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4330 - accuracy: 0.8035 - val_loss: 0.4677 - val_accuracy: 0.7689
# Epoch 40/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.7856 - val_loss: 0.4641 - val_accuracy: 0.7701
# Epoch 41/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.7985 - val_loss: 0.4730 - val_accuracy: 0.7677
# Epoch 42/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8028 - val_loss: 0.4713 - val_accuracy: 0.7820
# Epoch 43/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7946 - val_loss: 0.4627 - val_accuracy: 0.7749
# Epoch 44/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8011 - val_loss: 0.4629 - val_accuracy: 0.7689
# Epoch 45/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4372 - accuracy: 0.7949 - val_loss: 0.4630 - val_accuracy: 0.7749
# Epoch 46/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.8119 - val_loss: 0.4675 - val_accuracy: 0.7820
# Epoch 47/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.8086 - val_loss: 0.4672 - val_accuracy: 0.7760
# Epoch 48/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8034 - val_loss: 0.4740 - val_accuracy: 0.7737
# Epoch 49/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.7980 - val_loss: 0.4610 - val_accuracy: 0.7749
# Epoch 50/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.7951 - val_loss: 0.4622 - val_accuracy: 0.7808
# Epoch 51/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8107 - val_loss: 0.4705 - val_accuracy: 0.7820
# Epoch 52/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4322 - accuracy: 0.7999 - val_loss: 0.4735 - val_accuracy: 0.7784
# Epoch 53/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4161 - accuracy: 0.8111 - val_loss: 0.4616 - val_accuracy: 0.7760
# Epoch 54/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4288 - accuracy: 0.8028 - val_loss: 0.4725 - val_accuracy: 0.7689
# Epoch 55/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8019 - val_loss: 0.4669 - val_accuracy: 0.7772
# Epoch 56/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4220 - accuracy: 0.7971 - val_loss: 0.4623 - val_accuracy: 0.7725
# Epoch 57/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8182 - val_loss: 0.4796 - val_accuracy: 0.7689
# Epoch 58/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8002 - val_loss: 0.4710 - val_accuracy: 0.7784
# Epoch 59/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8103 - val_loss: 0.4608 - val_accuracy: 0.7760
# Epoch 60/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.7994 - val_loss: 0.4646 - val_accuracy: 0.7808
# Epoch 61/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8031 - val_loss: 0.4827 - val_accuracy: 0.7677
# Epoch 62/64
# 46/46 [==============================] - 0s 3ms/step - loss: 0.4274 - accuracy: 0.8022 - val_loss: 0.4648 - val_accuracy: 0.7784
# Epoch 63/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.7925 - val_loss: 0.4612 - val_accuracy: 0.7760
# Epoch 64/64
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.7889 - val_loss: 0.4602 - val_accuracy: 0.7844
